# %%
#Import the csv dataset files
import pandas as pd
Links=pd.read_csv(r"C:\Users\T2Gic\Downloads\archive (2)\links.csv") 
Movies=pd.read_csv(r"C:\Users\T2Gic\Downloads\archive (2)\movies.csv")
Ratings=pd.read_csv(r"C:\Users\T2Gic\Downloads\archive (2)\ratings.csv")
Tags=pd.read_csv(r"C:\Users\T2Gic\Downloads\archive (2)\tags.csv")

# %%
# Check for missing values
print(Links.isnull().sum())#links have 8 missing values
print(Movies.isnull().sum())
print(Tags.isnull().sum())
print(Ratings.isnull().sum())
# Out:
# movieId    0
# imdbId     0
# tmdbId     8
# dtype: int64
# movieId    0
# title      0
# genres     0
# dtype: int64
# userId       0
# movieId      0
# tag          0
# timestamp    0
# dtype: int64
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
#Drop the missing values
Links.dropna(subset=['tmdbId'], inplace=True)

# %%
#Check to see if the missing values have been dropped in the file
print(Links.isnull().sum())
# Out:
# movieId    0
# imdbId     0
# tmdbId     8
# dtype: int64
# movieId    0
# title      0
# genres     0
# dtype: int64
# userId       0
# movieId      0
# tag          0
# timestamp    0
# dtype: int64
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
#Check for true duplicate values
Links.duplicated().sum()
Movies.duplicated().sum()
Ratings.duplicated().sum()
Tags.duplicated().sum()
#Final output shows no full duplicate rows
# Out:
# np.int64(0)
